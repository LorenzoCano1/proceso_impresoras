# %% [markdown]
# # Librerias

# %%
import requests
from bs4 import BeautifulSoup
import MySQLdb
import datetime
from requests.exceptions import ConnectionError, ConnectTimeout, ReadTimeout

# %% [markdown]
# # Variables

# %%
vias = ["10.1.70.1", "10.1.70.2", "10.1.70.3", "10.1.70.4",
"10.2.70.1", "10.2.70.2", "10.2.70.3", "10.2.70.4",
"10.3.70.1","10.3.70.2", "10.3.70.3", "10.3.70.4", "10.3.70.5",
"10.4.70.1", "10.4.70.2", "10.4.70.3", "10.4.70.4", "10.4.70.5",
"10.5.70.1", "10.5.70.2", "10.5.70.3", "10.5.70.4", "10.5.70.5", "10.5.70.6", "10.5.70.7", "10.5.70.8", "10.5.70.10",
"10.6.70.1", "10.6.70.2", "10.6.70.3", "10.6.70.4", "10.6.70.5", "10.6.70.6", "10.6.70.7", "10.6.70.8",
"10.7.70.1", "10.7.70.2", "10.7.70.3", "10.7.70.4", "10.7.70.5", "10.7.70.6",
"10.8.70.1", "10.8.70.2", "10.8.70.3", "10.8.70.4", "10.8.70.5", "10.8.70.6", "10.8.70.7", "10.8.70.8", "10.8.70.9", "10.8.70.10",
"10.8.70.11", "10.8.70.12", "10.8.70.13", "10.8.70.14", "10.8.70.15", "10.8.70.16", "10.8.70.17", "10.8.70.18", "10.8.70.19", "10.8.70.20",
"10.8.70.21", "10.8.70.22", "10.8.70.23", "10.8.70.24", "10.8.70.25", "10.8.70.26", "10.8.70.27", "10.8.70.28", "10.8.70.29", "10.8.70.30",
"10.8.70.31", "10.8.70.32", "10.8.70.41", "10.8.70.42", "10.8.70.43", "10.8.70.44", "10.8.70.45", 
"10.9.70.1", "10.9.70.2", "10.9.70.3", "10.9.70.4",
"10.10.70.1", "10.10.70.2", "10.10.70.3", "10.10.70.4",
"10.11.70.1", "10.11.70.2",
"10.12.70.1", "10.12.70.2", "10.12.70.3", "10.12.70.4", "10.12.70.5", "10.12.70.6",
"10.13.70.1", "10.13.70.2", "10.13.70.3", "10.13.70.4",
"10.14.70.1", "10.14.70.2", "10.14.70.3", "10.14.70.4",
"10.15.70.1", "10.15.70.2", "10.15.70.3", "10.15.70.4",
"10.16.70.1", "10.16.70.2", "10.16.70.3", "10.16.70.4",
"10.17.70.1", "10.17.70.2", "10.17.70.3", "10.17.70.4",
"10.18.70.1", "10.18.70.2", "10.18.70.3", "10.18.70.4", "10.18.70.5", "10.18.70.6", "10.18.70.7", "10.18.70.8", "10.18.70.9", "10.18.70.10", 
"10.18.70.11", "10.18.70.12", "10.18.70.13", "10.18.70.14", "10.18.70.15", "10.18.70.16", "10.18.70.17", "10.18.70.18"]



# Crear una lista para almacenar los valores cuando se produce una excepción
ip_error = []

# %% [markdown]
# # Clases

# %%
class MySQLDatabase:
    def __init__(self, host, user, password, database, charset='latin1'):
        self.host = host
        self.user = user
        self.password = password
        self.database = database
        self.charset = charset
        self.connection = None

    def connect(self):
        try:
            self.connection = MySQLdb.connect(
                host=self.host,
                user=self.user,
                password=self.password,
                database=self.database,
                charset=self.charset
            )
            print("Conexión exitosa a la base de datos.")
        except MySQLdb.Error as e:
            print("Error al conectar a la base de datos:", e)

    def execute_query(self, query, values=None):
        if self.connection:
            try:
                cursor = self.connection.cursor()
                if values:
                    cursor.execute(query, values)
                else:
                    cursor.execute(query)
                result = cursor.fetchall()
                cursor.close()
                return result
            except MySQLdb.Error as e:
                print("Error al ejecutar la consulta:", e)
        else:
            print("No hay una conexión a la base de datos.")

    def commit(self):
        if self.connection:
            try:
                self.connection.commit()
                print("Cambios guardados en la base de datos.")
            except MySQLdb.Error as e:
                self.connection.rollback()
                print("Error al guardar cambios en la base de datos:", e)

    def close(self):
        if self.connection:
            self.connection.close()
            print("Conexión cerrada.")
        else:
            print("No hay una conexión activa para cerrar.")

# %% [markdown]
# # Obtencion de variables

# %%
# Nombre del archivo de configuración
config_file = "config.txt"

# Leer los datos desde el archivo de configuración
config = {}
with open(config_file, "r") as file:
    for line in file:
        key, value = line.strip().split(": ")
        config[key] = value

# %%
# Uso de la clase en un Jupyter Notebook
db = MySQLDatabase(
    host=config.get("Host"),
    user=config.get("User"),
    password=config.get("Password"),
    database=config.get("Database"),
    charset='latin1'
)

# %% [markdown]
# # ETL

# %%
db.connect()


for ip in vias:
    

    url = f'http://user:9999@{ip}/audit.html'
    headers = {
        'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.106 Safari/537.36'
    }

    # Realizar la solicitud GET y obtener el contenido HTML
    try:
        response = requests.get(url, headers=headers, timeout=150)
        html = response.content

        # Crear un objeto BeautifulSoup
        soup = BeautifulSoup(html, 'html.parser')

        input_element = soup.find('input', {'name': 'DATAFORMATZETA'})

        # Obtener el valor del atributo 'value' del elemento <input>
        valor = int(input_element['value']) - 1
        
        # Obtener la fecha y hora actual
        fecha_hora = datetime.datetime.now()
        # Restar un día
        un_dia = datetime.timedelta(days=1)
        fecha_hora = fecha_hora - un_dia
        fecha_hora = fecha_hora.date()
        
        # Sentencia SQL para la inserción
        sentencia_sql = "INSERT INTO ip_gco (ip, zeta, fecha) VALUES (%s, %s, %s)"

        # Verificar que la conexión a la base de datos esté abierta
        if db.connection is None:
            db.connect()

        print(f"Valor: {valor} de la ip: {ip}")
        
        # Valores a insertar
        valores = (ip, valor, fecha_hora)

        # Ejecutar la sentencia SQL
        db.execute_query(sentencia_sql, valores)
        db.commit()

    except ConnectionError as e:
        if isinstance(e, ConnectTimeout):
            # Manejar el error de tiempo de conexión (ConnectTimeout)
            print(f"Error ConnectTimeout a la ip: {ip}, el error es: {type(e).__name__}")
        elif isinstance(e, ReadTimeout):
            # Manejar el error de tiempo de lectura (ReadTimeout)
            print(f"Error ReadTimeout a la ip: {ip}, el error es: {type(e).__name__}")
            ip_error.append(ip)
        else:
            # Otros errores de conexión
            print(f"Otro error a la ip: {ip}, el error es: {type(e).__name__}")
    except Exception as e:
        # Manejar otras excepciones (si es necesario)
        print(f"Otro Error de la ip: {ip} tipo de excepcion {type(e).__name__}")
    
        
# Cerrar la conexión
db.close()
# Out:
# Conexión exitosa a la base de datos.
# Valor: 1741 de la ip: 10.1.70.1
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.1.70.1-1741-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Error ConnectTimeout a la ip: 10.1.70.2, el error es: ConnectTimeout
# Valor: 1735 de la ip: 10.1.70.3
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.1.70.3-1735-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Error ConnectTimeout a la ip: 10.1.70.4, el error es: ConnectTimeout
# Valor: 964 de la ip: 10.2.70.1
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.2.70.1-964-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Error ConnectTimeout a la ip: 10.2.70.2, el error es: ConnectTimeout
# Valor: 942 de la ip: 10.2.70.3
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.2.70.3-942-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Error ConnectTimeout a la ip: 10.2.70.4, el error es: ConnectTimeout
# Valor: 956 de la ip: 10.3.70.1
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.3.70.1-956-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1655 de la ip: 10.3.70.2
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.3.70.2-1655-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Error ConnectTimeout a la ip: 10.3.70.3, el error es: ConnectTimeout
# Valor: 947 de la ip: 10.3.70.4
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.3.70.4-947-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Error ConnectTimeout a la ip: 10.3.70.5, el error es: ConnectTimeout
# Valor: 1242 de la ip: 10.4.70.1
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.4.70.1-1242-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 2615 de la ip: 10.4.70.2
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.4.70.2-2615-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Error ConnectTimeout a la ip: 10.4.70.3, el error es: ConnectTimeout
# Valor: 890 de la ip: 10.4.70.4
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.4.70.4-890-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Error ConnectTimeout a la ip: 10.4.70.5, el error es: ConnectTimeout
# Error ConnectTimeout a la ip: 10.5.70.1, el error es: ConnectTimeout
# Valor: 1051 de la ip: 10.5.70.2
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.5.70.2-1051-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Error ConnectTimeout a la ip: 10.5.70.3, el error es: ConnectTimeout
# Valor: 1004 de la ip: 10.5.70.4
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.5.70.4-1004-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1005 de la ip: 10.5.70.5
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.5.70.5-1005-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 995 de la ip: 10.5.70.6
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.5.70.6-995-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1047 de la ip: 10.5.70.7
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.5.70.7-1047-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Error ConnectTimeout a la ip: 10.5.70.8, el error es: ConnectTimeout
# Valor: 1002 de la ip: 10.5.70.10
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.5.70.10-1002-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1737 de la ip: 10.6.70.1
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.6.70.1-1737-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1815 de la ip: 10.6.70.2
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.6.70.2-1815-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1722 de la ip: 10.6.70.3
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.6.70.3-1722-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Error ConnectTimeout a la ip: 10.6.70.4, el error es: ConnectTimeout
# Valor: 358 de la ip: 10.6.70.5
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.6.70.5-358-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1845 de la ip: 10.6.70.6
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.6.70.6-1845-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 385 de la ip: 10.6.70.7
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.6.70.7-385-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Error ConnectTimeout a la ip: 10.6.70.8, el error es: ConnectTimeout
# Valor: 1820 de la ip: 10.7.70.1
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.7.70.1-1820-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 399 de la ip: 10.7.70.2
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.7.70.2-399-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Error ConnectTimeout a la ip: 10.7.70.3, el error es: ConnectTimeout
# Valor: 2022 de la ip: 10.7.70.4
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.7.70.4-2022-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 2022 de la ip: 10.7.70.5
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.7.70.5-2022-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Error ConnectTimeout a la ip: 10.7.70.6, el error es: ConnectTimeout
# Valor: 1277 de la ip: 10.8.70.1
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.8.70.1-1277-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1193 de la ip: 10.8.70.2
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.8.70.2-1193-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1257 de la ip: 10.8.70.3
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.8.70.3-1257-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1199 de la ip: 10.8.70.4
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.8.70.4-1199-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1174 de la ip: 10.8.70.5
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.8.70.5-1174-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 891 de la ip: 10.8.70.6
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.8.70.6-891-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1304 de la ip: 10.8.70.7
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.8.70.7-1304-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1189 de la ip: 10.8.70.8
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.8.70.8-1189-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1214 de la ip: 10.8.70.9
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.8.70.9-1214-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1290 de la ip: 10.8.70.10
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.8.70.10-1290-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1359 de la ip: 10.8.70.11
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.8.70.11-1359-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1266 de la ip: 10.8.70.12
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.8.70.12-1266-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1438 de la ip: 10.8.70.13
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.8.70.13-1438-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Error ConnectTimeout a la ip: 10.8.70.14, el error es: ConnectTimeout
# Valor: 1294 de la ip: 10.8.70.15
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.8.70.15-1294-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1488 de la ip: 10.8.70.16
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.8.70.16-1488-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 258 de la ip: 10.8.70.17
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.8.70.17-258-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Error ConnectTimeout a la ip: 10.8.70.18, el error es: ConnectTimeout
# Valor: 1520 de la ip: 10.8.70.19
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.8.70.19-1520-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1305 de la ip: 10.8.70.20
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.8.70.20-1305-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1234 de la ip: 10.8.70.21
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.8.70.21-1234-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1072 de la ip: 10.8.70.22
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.8.70.22-1072-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1320 de la ip: 10.8.70.23
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.8.70.23-1320-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1241 de la ip: 10.8.70.24
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.8.70.24-1241-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1203 de la ip: 10.8.70.25
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.8.70.25-1203-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1220 de la ip: 10.8.70.26
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.8.70.26-1220-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1133 de la ip: 10.8.70.27
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.8.70.27-1133-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1128 de la ip: 10.8.70.28
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.8.70.28-1128-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1171 de la ip: 10.8.70.29
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.8.70.29-1171-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1223 de la ip: 10.8.70.30
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.8.70.30-1223-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1231 de la ip: 10.8.70.31
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.8.70.31-1231-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 2084 de la ip: 10.8.70.32
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.8.70.32-2084-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1543 de la ip: 10.8.70.41
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.8.70.41-1543-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1603 de la ip: 10.8.70.42
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.8.70.42-1603-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1671 de la ip: 10.8.70.43
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.8.70.43-1671-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1798 de la ip: 10.8.70.44
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.8.70.44-1798-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1944 de la ip: 10.8.70.45
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.8.70.45-1944-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 2464 de la ip: 10.9.70.1
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.9.70.1-2464-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Error ConnectTimeout a la ip: 10.9.70.2, el error es: ConnectTimeout
# Valor: 2755 de la ip: 10.9.70.3
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.9.70.3-2755-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Error ConnectTimeout a la ip: 10.9.70.4, el error es: ConnectTimeout
# Valor: 2731 de la ip: 10.10.70.1
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.10.70.1-2731-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Error ConnectTimeout a la ip: 10.10.70.2, el error es: ConnectTimeout
# Valor: 2854 de la ip: 10.10.70.3
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.10.70.3-2854-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Error ConnectTimeout a la ip: 10.10.70.4, el error es: ConnectTimeout
# Valor: 2839 de la ip: 10.11.70.1
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.11.70.1-2839-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Error ConnectTimeout a la ip: 10.11.70.2, el error es: ConnectTimeout
# Valor: 2061 de la ip: 10.12.70.1
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.12.70.1-2061-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1740 de la ip: 10.12.70.2
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.12.70.2-1740-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Error ConnectTimeout a la ip: 10.12.70.3, el error es: ConnectTimeout
# Valor: 183 de la ip: 10.12.70.4
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.12.70.4-183-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1538 de la ip: 10.12.70.5
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.12.70.5-1538-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Error ConnectTimeout a la ip: 10.12.70.6, el error es: ConnectTimeout
# Valor: 2063 de la ip: 10.13.70.1
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.13.70.1-2063-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Error ConnectTimeout a la ip: 10.13.70.2, el error es: ConnectTimeout
# Valor: 2169 de la ip: 10.13.70.3
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.13.70.3-2169-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Error ConnectTimeout a la ip: 10.13.70.4, el error es: ConnectTimeout
# Valor: 2155 de la ip: 10.14.70.1
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.14.70.1-2155-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Error ConnectTimeout a la ip: 10.14.70.2, el error es: ConnectTimeout
# Valor: 2190 de la ip: 10.14.70.3
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.14.70.3-2190-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Error ConnectTimeout a la ip: 10.14.70.4, el error es: ConnectTimeout
# Valor: 2107 de la ip: 10.15.70.1
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.15.70.1-2107-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Error ConnectTimeout a la ip: 10.15.70.2, el error es: ConnectTimeout
# Valor: 2114 de la ip: 10.15.70.3
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.15.70.3-2114-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Error ConnectTimeout a la ip: 10.15.70.4, el error es: ConnectTimeout
# Valor: 2104 de la ip: 10.16.70.1
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.16.70.1-2104-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Error ConnectTimeout a la ip: 10.16.70.2, el error es: ConnectTimeout
# Valor: 2630 de la ip: 10.16.70.3
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.16.70.3-2630-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Error ConnectTimeout a la ip: 10.16.70.4, el error es: ConnectTimeout
# Valor: 2010 de la ip: 10.17.70.1
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.17.70.1-2010-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Error ConnectTimeout a la ip: 10.17.70.2, el error es: ConnectTimeout
# Valor: 2176 de la ip: 10.17.70.3
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.17.70.3-2176-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Error ConnectTimeout a la ip: 10.17.70.4, el error es: ConnectTimeout
# Valor: 1510 de la ip: 10.18.70.1
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.18.70.1-1510-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1382 de la ip: 10.18.70.2
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.18.70.2-1382-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1162 de la ip: 10.18.70.3
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.18.70.3-1162-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 361 de la ip: 10.18.70.4
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.18.70.4-361-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1103 de la ip: 10.18.70.5
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.18.70.5-1103-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1303 de la ip: 10.18.70.6
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.18.70.6-1303-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1654 de la ip: 10.18.70.7
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.18.70.7-1654-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1518 de la ip: 10.18.70.8
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.18.70.8-1518-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1489 de la ip: 10.18.70.9
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.18.70.9-1489-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Error ConnectTimeout a la ip: 10.18.70.10, el error es: ConnectTimeout
# Error ConnectTimeout a la ip: 10.18.70.11, el error es: ConnectTimeout
# Valor: 1662 de la ip: 10.18.70.12
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.18.70.12-1662-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1259 de la ip: 10.18.70.13
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.18.70.13-1259-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1234 de la ip: 10.18.70.14
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.18.70.14-1234-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1217 de la ip: 10.18.70.15
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.18.70.15-1217-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1179 de la ip: 10.18.70.16
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.18.70.16-1179-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1253 de la ip: 10.18.70.17
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.18.70.17-1253-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Valor: 1668 de la ip: 10.18.70.18
# Error al ejecutar la consulta: (1062, "Duplicate entry '10.18.70.18-1668-2023-09-12' for key 'PRIMARY'")
# Cambios guardados en la base de datos.
# Conexión cerrada.

# %%
print(ip_error)
# Out:
# []

# %%
db.connect()
for ip in ip_error:

    # Obtener la fecha y hora actual
    fecha_hora = datetime.datetime.now()
    # Restar un día
    un_dia = datetime.timedelta(days=1)
    fecha_hora = fecha_hora - un_dia
    fecha_hora = fecha_hora.date()
    # Sentencia SQL para la inserción
    sentencia_sql = "INSERT INTO ip_zeta_error (ip, fecha) VALUES (%s, %s)"


    # Valores a insertar
    valores = (ip, fecha_hora)

    # Ejecutar la sentencia SQL
    db.execute_query(sentencia_sql, valores)
    db.commit()


db.close()
# Out:
# Conexión exitosa a la base de datos.
# Conexión cerrada.

# %%
#for via in vias:
#    try:
#        tiempo_respuesta = ping3.ping(via)
#        if tiempo_respuesta is not None:
#            print(f"{via} está disponible (Tiempo de respuesta: {tiempo_respuesta} ms)")
#        else:
#            print(f"{via} no está disponible")
#    except Exception as e:
#        print(f"Error al realizar ping a {via}: {e}")
